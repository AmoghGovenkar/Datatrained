# %% [markdown]
# # #World Happiness Report

# %% [markdown]
# Problem Statement:
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %%
#Linear algebra
import numpy as np
#data processing
import pandas as pd
#data visiulization library
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# loading dataset
df=pd.read_csv('Happiness_report.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
# checking the data shape
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# checking the data set information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
# checking the missing value
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# exploring data analysis
#printing the object type and their unique code
for column in df.columns:
    if df[column].dtype==object:
        print(str(column)+ " : " +str(df[column].unique()))
        print(df[column].value_counts())
        print("--------------------------------------------------------------------------------------")
        print("\n")
# Out:
# Country : ['Switzerland' 'Iceland' 'Denmark' 'Norway' 'Canada' 'Finland'
#  'Netherlands' 'Sweden' 'New Zealand' 'Australia' 'Israel' 'Costa Rica'
#  'Austria' 'Mexico' 'United States' 'Brazil' 'Luxembourg' 'Ireland'
#  'Belgium' 'United Arab Emirates' 'United Kingdom' 'Oman' 'Venezuela'
#  'Singapore' 'Panama' 'Germany' 'Chile' 'Qatar' 'France' 'Argentina'
#  'Czech Republic' 'Uruguay' 'Colombia' 'Thailand' 'Saudi Arabia' 'Spain'
#  'Malta' 'Taiwan' 'Kuwait' 'Suriname' 'Trinidad and Tobago' 'El Salvador'
#  'Guatemala' 'Uzbekistan' 'Slovakia' 'Japan' 'South Korea' 'Ecuador'
#  'Bahrain' 'Italy' 'Bolivia' 'Moldova' 'Paraguay' 'Kazakhstan' 'Slovenia'
#  'Lithuania' 'Nicaragua' 'Peru' 'Belarus' 'Poland' 'Malaysia' 'Croatia'
#  'Libya' 'Russia' 'Jamaica' 'North Cyprus' 'Cyprus' 'Algeria' 'Kosovo'
#  'Turkmenistan' 'Mauritius' 'Hong Kong' 'Estonia' 'Indonesia' 'Vietnam'
#  'Turkey' 'Kyrgyzstan' 'Nigeria' 'Bhutan' 'Azerbaijan' 'Pakistan' 'Jordan'
#  'Montenegro' 'China' 'Zambia' 'Romania' 'Serbia' 'Portugal' 'Latvia'
#  'Philippines' 'Somaliland region' 'Morocco' 'Macedonia' 'Mozambique'
#  'Albania' 'Bosnia and Herzegovina' 'Lesotho' 'Dominican Republic' 'Laos'
#  'Mongolia' 'Swaziland' 'Greece' 'Lebanon' 'Hungary' 'Honduras'
#  'Tajikistan' 'Tunisia' 'Palestinian Territories' 'Bangladesh' 'Iran'
#  'Ukraine' 'Iraq' 'South Africa' 'Ghana' 'Zimbabwe' 'Liberia' 'India'
#  'Sudan' 'Haiti' 'Congo (Kinshasa)' 'Nepal' 'Ethiopia' 'Sierra Leone'
#  'Mauritania' 'Kenya' 'Djibouti' 'Armenia' 'Botswana' 'Myanmar' 'Georgia'
#  'Malawi' 'Sri Lanka' 'Cameroon' 'Bulgaria' 'Egypt' 'Yemen' 'Angola'
#  'Mali' 'Congo (Brazzaville)' 'Comoros' 'Uganda' 'Senegal' 'Gabon' 'Niger'
#  'Cambodia' 'Tanzania' 'Madagascar' 'Central African Republic' 'Chad'
#  'Guinea' 'Ivory Coast' 'Burkina Faso' 'Afghanistan' 'Rwanda' 'Benin'
#  'Syria' 'Burundi' 'Togo']
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
# --------------------------------------------------------------------------------------
#
#
# Region : ['Western Europe' 'North America' 'Australia and New Zealand'
#  'Middle East and Northern Africa' 'Latin America and Caribbean'
#  'Southeastern Asia' 'Central and Eastern Europe' 'Eastern Asia'
#  'Sub-Saharan Africa' 'Southern Asia']
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
# --------------------------------------------------------------------------------------

# %% [markdown]
# # Eda

# %%
Happiness_Score=df["Happiness Score"].hist(bins=60)
mean_val=np.mean(df["Happiness Score"])
plt.axvline(mean_val,linewidth=4,color="blue",label="Mean Happiness")
plt.xlabel("Happiness Score")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(25,10))
mean_happiness=np.mean(df["Happiness Score"])
sns.barplot(x="Country",y="Happiness Score",data=df,palette="rainbow")
plt.axhline(mean_happiness,color="b",linestyle="dashed",linewidth=5)
plt.title("Happiness vs Country",fontsize=18)
plt.xticks(rotation="vertical")
plt.show()
print(df["Happiness Score"].value_counts())
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Happiness Score",data=df,palette="rainbow")
plt.xticks(rotation=30)
plt.show()
print(df["Region"].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Economy (GDP per Capita)",data=df,palette="BuPu")
plt.xticks(rotation=30)
plt.show()
print(df.groupby("Region")["Economy (GDP per Capita)"].value_counts())
# Out:
# Region                      Economy (GDP per Capita)
# Australia and New Zealand   1.25018                     1
#                             1.33358                     1
# Central and Eastern Europe  0.39047                     1
#                             0.47428                     1
#                             0.59448                     1
#                                                        ..
# Western Europe              1.33596                     1
#                             1.33723                     1
#                             1.39651                     1
#                             1.45900                     1
#                             1.56391                     1
# Name: Economy (GDP per Capita), Length: 158, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Health (Life Expectancy)",data=df,palette="Dark2")
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Freedom",data=df,palette="GnBu")
plt.xticks(rotation=30)
plt.show()
print(df.groupby("Region")["Freedom"].value_counts())
# Out:
# Region                      Freedom
# Australia and New Zealand   0.63938    1
#                             0.65124    1
# Central and Eastern Europe  0.09245    1
#                             0.18260    1
#                             0.19847    1
#                                       ..
# Western Europe              0.64169    1
#                             0.64938    1
#                             0.65980    1
#                             0.66557    1
#                             0.66973    1
# Name: Freedom, Length: 158, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Trust (Government Corruption)",data=df,palette="Greys")
plt.xticks(rotation=30)
plt.show()
print(df.groupby("Region")["Trust (Government Corruption)"].value_counts())
# Out:
# Region                      Trust (Government Corruption)
# Australia and New Zealand   0.35637                          1
#                             0.42922                          1
# Central and Eastern Europe  0.00227                          1
#                             0.00649                          1
#                             0.00872                          1
#                                                             ..
# Western Europe              0.37798                          1
#                             0.41372                          1
#                             0.41978                          1
#                             0.43844                          1
#                             0.48357                          1
# Name: Trust (Government Corruption), Length: 157, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Generosity",data=df,palette="PRGn_r")
plt.xticks(rotation=30)
plt.show()
print(df.groupby("Region")["Generosity"].value_counts())
# Out:
# Region                      Generosity
# Australia and New Zealand   0.43562       1
#                             0.47501       1
# Central and Eastern Europe  0.00199       1
#                             0.02641       1
#                             0.05444       1
#                                          ..
# Western Europe              0.43630       1
#                             0.45901       1
#                             0.47610       1
#                             0.51752       1
#                             0.51912       1
# Name: Generosity, Length: 158, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Region",y="Dystopia Residual",data=df,palette="RdPu")
plt.xticks(rotation=30)
plt.show()
print(df.groupby("Dystopia Residual")["Region"].value_counts())
# Out:
# Dystopia Residual  Region
# 0.32858            Middle East and Northern Africa    1
# 0.65429            Eastern Asia                       1
# 0.67042            Sub-Saharan Africa                 1
# 0.67108            Southern Asia                      1
# 0.89991            Central and Eastern Europe         1
#                                                      ..
# 3.10712            Central and Eastern Europe         1
# 3.17728            Latin America and Caribbean        1
# 3.19131            Latin America and Caribbean        1
# 3.26001            Latin America and Caribbean        1
# 3.60214            Latin America and Caribbean        1
# Name: Region, Length: 158, dtype: int64

# %%
# handling categorical data
df.drop(['Country','Region'],axis=1,inplace=True)

# %% [markdown]
# # Summary Statistic

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %% [markdown]
# # Correlation

# %%
corr=df
corr.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
plt.figure(figsize=(15,10))
df.drop("Happiness Score",axis=1).corrwith(df["Happiness Score"]).plot(kind="bar",grid=True)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# # Plotting Outliers

# %%
df["Happiness Rank"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Standard Error"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Family"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing Outliers

# %%
#for outliers remove i will apply zscore
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0          1.721000         1.937360        0.805926
# 1          1.699075         1.914581        0.055889
# 2          1.677149         1.884792        0.854487
# 3          1.655224         1.880411        0.531526
# 4          1.633299         1.797179        0.722845
# ..              ...              ...             ...
# 153        1.633576         1.674055        0.774917
# 154        1.655501         1.783571        0.662582
# 155        1.677427         2.076199        0.132534
# 156        1.699352         2.164688        2.263962
# 157        1.721277         2.222513        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# 2                    1.192861  1.361054                  0.992229  1.469659
# 3                    1.525130  1.251922                  1.035145  1.605131
# 4                    1.194876  1.221204                  1.118054  1.360416
# ..                        ...       ...                       ...       ...
# 153                  1.552987  0.800520                  0.818610  1.087740
# 154                  1.392303  2.346860                  1.263362  0.372033
# 155                  0.455245  1.901086                  0.372199  1.809238
# 156                  2.067566  2.118467                  1.649648  2.064472
# 157                  1.586334  3.134725                  1.404129  0.426621
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                         2.309652    0.471040           0.758258
# 1                         0.016480    1.575856           1.092857
# 2                         2.842774    0.824293           0.712335
# 3                         1.852081    0.868638           0.663893
# 4                         1.555725    1.748563           0.639337
# ..                             ...         ...                ...
# 153                       3.413922    0.087228           2.588925
# 154                       0.529210    0.433117           0.843967
# 155                       0.381419    1.856891           3.208430
# 156                       0.357715    0.316950           0.481985
# 157                       0.301803    0.558153           0.963612
#
# [158 rows x 10 columns]

# %%
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
train=df[(z<3).all(axis=1)]

# %%
print(train.shape)
print(df.shape)
# Out:
# (149, 10)
# (158, 10)

# %% [markdown]
# # Checking Skewness

# %%
train.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
for col in train.describe().columns:
    sns.distplot(train[col],color="r")
    plt.show()

# %%
#removing skewness from the columns by using sqrt and cbrt method.
train.skew()
for col in train.skew().index:
    if col in train.describe().columns:
        if train[col].skew()>0.55:
            train[col]=np.sqrt(train[col])
        if train[col].skew()<0.55:
            train[col]=np.cbrt(train[col])

# %% [markdown]
# # Feature Selection

# %%
x=train.drop(columns=["Happiness Score"],axis=1)
y=train["Happiness Score"]

# %%
#apply standard scaler to come all the to one scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
print(x)
# Out:
# [[-2.94706931e+00 -9.03988786e-01  1.03886048e+00 ...  1.57517471e+00
#    5.44216772e-01  7.59306720e-01]
#  [-2.69464805e+00  2.64414097e-01  9.05652587e-01 ...  3.26689007e-01
#    1.09255234e+00  1.04903286e+00]
#  [-2.51758045e+00 -9.76742339e-01  9.38987099e-01 ...  1.75481104e+00
#    7.39423854e-01  7.18448298e-01]
#  ...
#  [ 1.27594039e+00 -1.19604168e+00 -1.20863190e+00 ... -5.41316784e-02
#    8.34653029e-01 -2.27089847e-01]
#  [ 1.29847497e+00 -6.94249675e-01 -1.33558918e+00 ... -2.41274193e-01
#   -9.85977976e-02 -8.70504947e-01]
#  [ 1.32081653e+00  2.62147495e+00 -3.46498748e+00 ... -1.99266821e-02
#    2.27511485e-04 -4.58578606e-01]]

# %% [markdown]
# # Building Machine Learning Model

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (119, 9)
# (30, 9)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (119,)
# (30,)

# %%
#importing all library
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
#import boosting library
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
#import metrics library
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
#All algorithm using loop
model=[LinearRegression(),Lasso(),Ridge(),ElasticNet(),SVR(),DecisionTreeRegressor(),KNeighborsRegressor(),
      RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]
for m in model:
    m.fit(x_train,y_train)
    score=m.score(x_train,y_train)
    predm=m.predict(x_test)
    print("Score of",m,"is")
    print("MAE:",mean_absolute_error(y_test,predm))
    print("MSE:",mean_squared_error(y_test,predm))
    print("RSME:",np.sqrt(mean_squared_error(y_test,predm)))
    print("R2 Score:",r2_score(y_test,predm))
    print("***********************************************************************************")
    print("/n")
# Out:
# Score of LinearRegression() is
# MAE: 0.01282220422110251
# MSE: 0.00045661881865965206
# RSME: 0.021368641011062263
# R2 Score: 0.9663917546015636
# ***********************************************************************************
# /n
# Score of Lasso() is
# MAE: 0.09927412490130386
# MSE: 0.013588356448706127
# RSME: 0.11656910589305439
# R2 Score: -0.00013577940145115264
# ***********************************************************************************
# /n
# Score of Ridge() is
# MAE: 0.012779499022308608
# MSE: 0.0004557226661931389
# RSME: 0.021347661843704076
# R2 Score: 0.9664577135826179
# ***********************************************************************************
# /n
# Score of ElasticNet() is
# MAE: 0.09927412490130386
# MSE: 0.013588356448706127
# RSME: 0.11656910589305439
# R2 Score: -0.00013577940145115264
# ***********************************************************************************
# /n
# Score of SVR() is
# MAE: 0.04500087107946836
# MSE: 0.002832513974312129
# RSME: 0.05322136764789241
# R2 Score: 0.7915201457911483
# ***********************************************************************************
# /n
# Score of DecisionTreeRegressor() is
# MAE: 0.005021333765636685
# MSE: 5.0637282330290436e-05
# RSME: 0.007115987797227483
# R2 Score: 0.9962729739964248
# ***********************************************************************************
# /n
# Score of KNeighborsRegressor() is
# MAE: 0.023173503634176727
# MSE: 0.0008443886933797257
# RSME: 0.029058367011580773
# R2 Score: 0.9378509573870122
# ***********************************************************************************
# /n
# Score of RandomForestRegressor() is
# MAE: 0.0029997757254916157
# MSE: 1.6736248912634313e-05
# RSME: 0.0040909960782961295
# R2 Score: 0.9987681717495652
# ***********************************************************************************
# /n
# Score of AdaBoostRegressor() is
# MAE: 0.004716025501534279
# MSE: 4.309886574035101e-05
# RSME: 0.006564972638202768
# R2 Score: 0.9968278196232739
# ***********************************************************************************
# /n
# Score of GradientBoostingRegressor() is
# MAE: 0.002995495161138617
# MSE: 2.1620621534801148e-05
# RSME: 0.00464979801010766
# R2 Score: 0.9984086701543724
# ***********************************************************************************
# /n

# %%
#Cross val score For all algorithm
model=[LinearRegression(),Ridge(),DecisionTreeRegressor(),RandomForestRegressor(),AdaBoostRegressor(),
       GradientBoostingRegressor()]
for n in model:
    score=cross_val_score(n,x,y,cv=2,scoring="r2")
    print("Model:",n)
    print("Score:",score)
    print("Mean Score:",score.mean())
    print("StandardDeviation:",score.std())
    print("****************************************************************************************************")
    print("/n")
# Out:
# Model: LinearRegression()
# Score: [-1.86806077  0.67297508]
# Mean Score: -0.5975428409151535
# StandardDeviation: 1.2705179255395314
# ****************************************************************************************************
# /n
# Model: Ridge()
# Score: [0.29143816 0.60751027]
# Mean Score: 0.4494742148062965
# StandardDeviation: 0.15803605061572518
# ****************************************************************************************************
# /n
# Model: DecisionTreeRegressor()
# Score: [-3.23998135 -1.97409436]
# Mean Score: -2.60703785186864
# StandardDeviation: 0.6329434967494794
# ****************************************************************************************************
# /n
# Model: RandomForestRegressor()
# Score: [-3.21682158 -2.30200769]
# Mean Score: -2.759414635305049
# StandardDeviation: 0.4574069469110784
# ****************************************************************************************************
# /n
# Model: AdaBoostRegressor()
# Score: [-3.39289082 -2.29043669]
# Mean Score: -2.8416637550020205
# StandardDeviation: 0.5512270609075689
# ****************************************************************************************************
# /n
# Model: GradientBoostingRegressor()
# Score: [-2.93719134 -1.94983506]
# Mean Score: -2.4435132019814194
# StandardDeviation: 0.4936781378618247
# ****************************************************************************************************
# /n

# %%
#Using gridsearchcv to find out the best parameter in Ridge
from sklearn.linear_model import Ridge
parameters={"alpha":[0.001,.001,.01,.1,1,10],"random_state":list(range(0,33))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
rd=Ridge(alpha=10,random_state=0)
rd.fit(x_train,y_train)
predrd=rd.predict(x_test)
print("Score:",rd.score(x_train,y_train))
print("Mean Asolute Error:",mean_absolute_error(y_test,predrd))
print("Mean Squared Error:",mean_squared_error(y_test,predrd))
print("Root Mean Squared Error:",np.sqrt(y_test,predrd))
print("*********************************************************************************************************")
print("/n")
# Out:
# Score: 0.9742186296780778
# Mean Asolute Error: 0.013403970541612516
# Mean Squared Error: 0.0004703407822842221
# Root Mean Squared Error: 76     1.319840
# 18     1.381005
# 121    1.285469
# 81     1.315899
# 79     1.316742
# 32     1.365303
# 67     1.332793
# 145    1.248153
# 71     1.327550
# 85     1.313010
# 112    1.291569
# 12     1.389597
# 37     1.358941
# 9      1.392286
# 19     1.379808
# 58     1.340911
# 141    1.254830
# 72     1.325725
# 57     1.341334
# 136    1.261648
# 30     1.366285
# 127    1.276776
# 26     1.372001
# 132    1.272816
# 133    1.271114
# 150    1.241122
# 113    1.291151
# 104    1.298252
# 47     1.347068
# 31     1.365584
# Name: Happiness Score, dtype: float64
# *********************************************************************************************************
# /n

# %% [markdown]
# # Plotting in ridge regression

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predrd,color="r")
plt.plot(y_test,y_test,color="b")
plt.xlabel("Actual Score",fontsize=14)
plt.ylabel("Predicted Score",fontsize=14)
plt.title("Ridge Regression")
plt.show()

# %% [markdown]
# # Conclusion

# %%
import numpy as np
Country=np.array(y_test)

# %%
Predicted=np.array(rd.predict(x_test))

# %%
train=pd.DataFrame({"Country":Country,"Predicted":Predicted},index=range(len(Country)))

# %%
train
# Out:
#      Country  Predicted
# 0   1.741977   1.752417
# 1   1.907175   1.903348
# 2   1.652430   1.645493
# 3   1.731589   1.740994
# 4   1.733810   1.739852
# 5   1.864052   1.868752
# 6   1.776336   1.779359
# 7   1.557886   1.598013
# 8   1.762388   1.683511
# 9   1.723996   1.725288
# 10  1.668150   1.688412
# 11  1.930979   1.928449
# 12  1.846719   1.839992
# 13  1.938459   1.928193
# 14  1.903870   1.884984
# 15  1.798043   1.798863
# 16  1.574599   1.615735
# 17  1.757546   1.755519
# 18  1.799177   1.799797
# 19  1.591754   1.623246
# 20  1.866734   1.868633
# 21  1.630157   1.631340
# 22  1.882386   1.877213
# 23  1.620060   1.643977
# 24  1.615730   1.619966
# 25  1.540384   1.578053
# 26  1.667071   1.676026
# 27  1.685458   1.698957
# 28  1.814593   1.815075
# 29  1.864819   1.859148

# %% [markdown]
# # serialization

# %%
#importing pickle library
import pickle

# %%
filename="Happiness_report.pkl"
pickle.dump(rd,open(filename,"wb"))
